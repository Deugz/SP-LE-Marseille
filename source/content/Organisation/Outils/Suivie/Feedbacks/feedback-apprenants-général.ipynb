# %% [markdown]
# # Feedbacks Apprenants (Général)
#
# Ce Jupyter notebook est dédié a la gestion et au suivie des feedbacks des apprenants
#
# ## Process
#
# Chaque fin de semaine exporter le rapport (fichier excel), et lancer l'analyse
# - créer un rapport a envoyer au formateur

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Lire les fichier CSV
#
# ```{note}
# Actuellement, il faut télécharger les différentes données nécéssaires à l'execution de ce notebook.
#
# - Possibilité de récupérer directement les données depuis le drive ?
#
# ```

# %%
# Le résultat du formulaire de feedbacks des apprenants

#df_CDP1 = pd.read_csv('C:/Users/vdegu/3A_Alliance/Encyclopedia_3A/Viny_3A/TOPICS/Education/GROUND/SP-Label-Ecole/source/content/Organisation/Suivie/Feedbacks/data/data-07_02_25.csv')
df_CDP2 = pd.read_csv('C:/Users/vdegu/3A_Alliance/School_3A/Formations/Label-Ecole/Marseille/SP-LE-Marseille/source/content/Organisation/Outils/Suivie/Feedbacks/data/CDP2/data-13_05_25.csv', encoding='latin1')

df_test = pd.read_csv('C:/Users/vdegu/3A_Alliance/School_3A/Formations/Label-Ecole/Marseille/SP-LE-Marseille/source/content/Organisation/Outils/Suivie/Feedbacks/data/example/Feedback-CDP8.csv')

# Un tableau avec les noms prénoms des apprenant - créer une liste avec tout les prénoms

df_apprenants_CDP2 = pd.read_csv('C:/Users/vdegu/3A_Alliance/School_3A/Formations/Label-Ecole/Marseille/SP-LE-Marseille/source/content/Organisation/Outils/Suivie/Feedbacks/data/CDP2/CDP2-BDD.csv', encoding='latin1')

# %% [markdown]
# ```{warning}
#
# De quels informations on a besoin et comment les extraire ?
#
# - nombre total apprenant
#
# - liste de tout les apprenants
# - liste de tout les cours
#
#
# ```

# %%
df_CDP2
# Out:
#                                     # Quel est ton nom de famille ?  \
# 0    tnrtvrlt65j6tnrtvmrgri2zv061y90w                       EL ZANT
# 1    n57nft5vw3wplwyon57nftwoap24otra                       szklorz
# 2    grwptjks397km046ugrwptj1y22mexwv                           Roy
# 3    olt6yfe0wu202piolt6ye78l6rpjlqx3                       EL ZANT
# 4    fpkaeue5oi6cp2icgf5fpkaxcjem1sdl                         Sakho
# ..                                ...                           ...
# 139  a0uo5t72ecsw442ea0uo5ttem8zheg4o                       Amdouni
# 140  w2x0heh33lnrbrw2x06g2seim4g33ps8                         ALLAL
# 141  c77aex5ovypibmcvpbiaguuc77aexj5d                     DRISSAOUI
# 142  k05qna2yqkijsbpgk4ok05qnadpf8xb0                   Biancarelli
# 143  twe8idgr6txjc9c9pwvtwe8idelel4hx                         Sakho
#
#     Quel est ton prÃ©nomâ¯?  \
# 0                      Houss
# 1                     laszlo
# 2                      Manon
# 3                      Houss
# 4                   Zaccaria
# ..                       ...
# 139                  Soumaya
# 140                    Mehdi
# 141                 Mohammed
# 142                   Elodie
# 143                 Zaccaria
#
#                      Quel module veux-tu renseigner ?   \
# 0    Comprendre les utilisateurs pour scÃ©nariser l'UX
# 1                Savoir rÃ©aliser un benchmark digital
# 2                  Bien dÃ©marrer illustrator partie 3
# 3                                  Veille sur internet
# 4    Comprendre les utilisateurs pour scÃ©nariser l'UX
# ..                                                 ...
# 139   Comprendre l'impact du Marketing dans le digital
# 140   Comprendre l'impact du Marketing dans le digital
# 141   Comprendre l'impact du Marketing dans le digital
# 142   Comprendre l'impact du Marketing dans le digital
# 143   Comprendre l'impact du Marketing dans le digital
#
#     Comment te sens-tu Ã  l'issue de ce module ?  Pourquoi ?  \
# 0        Jâai appris de maniÃ¨re satisfaisante         NaN
# 1        Jâai appris de maniÃ¨re satisfaisante         NaN
# 2                         Jâai beaucoup appris         NaN
# 3        Jâai appris de maniÃ¨re satisfaisante         NaN
# 4        Jâai appris de maniÃ¨re satisfaisante         NaN
# ..                                           ...         ...
# 139                       Jâai beaucoup appris         NaN
# 140                       Jâai beaucoup appris         NaN
# 141                       Jâai beaucoup appris         NaN
# 142                       Jâai beaucoup appris         NaN
# 143      Jâai appris de maniÃ¨re satisfaisante         NaN
#
#     Le contenu  du module Ã©tait-il adaptÃ© Ã  tes attentes ? Pourquoi ?.1  \
# 0                                         Oui, plutÃ´t                 NaN
# 1                                         Oui, plutÃ´t                 NaN
# 2                                    Oui, tout Ã  fait                 NaN
# 3                                         Oui, plutÃ´t                 NaN
# 4                                         Oui, plutÃ´t                 NaN
# ..                                                 ...                 ...
# 139                                  Oui, tout Ã  fait                 NaN
# 140                                  Oui, tout Ã  fait                 NaN
# 141                                       Oui, plutÃ´t                 NaN
# 142                                       Oui, plutÃ´t                 NaN
# 143                                  Oui, tout Ã  fait                 NaN
#
#     As-tu le sentiment de maÃ®triser ce qui a Ã©tÃ© vu dans le module ?  \
# 0    Oui, mÃªme si je dois revoir certains points (...
# 1    Oui, mÃªme si je dois revoir certains points (...
# 2    Oui, j'ai tout compris ou presque (trÃ¨s bonne...
# 3    Oui, j'ai tout compris ou presque (trÃ¨s bonne...
# 4    Oui, mÃªme si je dois revoir certains points (...
# ..                                                 ...
# 139  Oui, j'ai tout compris ou presque (trÃ¨s bonne...
# 140  Oui, j'ai tout compris ou presque (trÃ¨s bonne...
# 141  Oui, j'ai tout compris ou presque (trÃ¨s bonne...
# 142  Oui, mÃªme si je dois revoir certains points (...
# 143  Oui, j'ai tout compris ou presque (trÃ¨s bonne...
#
#                                             Lesquels ?  ...  \
# 0       quelque aspect complÃ©mentaire concernant l'ux  ...
# 1    permet de prÃ©ciser des detail dans lapplicati...  ...
# 2                                                  NaN  ...
# 3                                                  NaN  ...
# 4                                Lâergonomie du site  ...
# ..                                                 ...  ...
# 139                                                NaN  ...
# 140                                                NaN  ...
# 141                                                NaN  ...
# 142                                   Btob btoC etc...  ...
# 143                                                NaN  ...
#
#     Peux-tu partager une chose que tu as retenue de ce module ?  \
# 0    l'impact que le travail bien fait, concernant ...
# 1    usage d'outil, suivi de campagne et planning d...
# 2                                                  NaN
# 3    Comment bien faire une veille et quel outils p...
# 4                                                  NaN
# ..                                                 ...
# 139                                            Seo Sea
# 140             Le jargon et vocabulaire du e commerce
# 141                                      Les mots clÃ©
# 142                           La complexitÃ© d'un site
# 143  Lâanalyse dâaudience qui permet de savoir ...
#
#                   Comment as-tu trouvÃ© le formateur ?  \
# 0                                        satisfaisante
# 1    EngagÃ© sur son domaine, forte comprÃ©hension ...
# 2                                                 Bien
# 3                          Merci Vincent c'Ã©tait bien
# 4                                                  NaN
# ..                                                 ...
# 139                                                Top
# 140  Super accessible (communication fluide) et bie...
# 141                                         TrÃ¨s bien
# 142             Excellente rayonnante trÃ¨s pÃ©dagogue
# 143            TrÃ¨s sympa et Ã  lâÃ©coute de chacun
#
#            As-tu des idÃ©es pour amÃ©liorer le cours ?  \
# 0                  peut-Ãªtre plus d'exercice pratique
# 1                                                  NaN
# 2                            Non câÃ©tait trÃ¨s bien
# 3    le cours en lui mÃªme pas forcÃ©ment, mais en ...
# 4                                                  NaN
# ..                                                 ...
# 139                                                Non
# 140                              En toute modestie non
# 141                                   Non pas vraiment
# 142                                         Tt est bon
# 143                                                NaN
#
#           Dâautres remarques ? Response Type     Start Date (UTC)  \
# 0              c'est tt pour moi     completed  2025-05-13 09:08:01
# 1                            NaN     completed  2025-05-13 09:05:31
# 2                            Non     completed  2025-05-13 09:04:44
# 3                         aucune     completed  2025-05-13 09:04:34
# 4                            NaN     completed  2025-05-13 09:04:34
# ..                           ...           ...                  ...
# 139                          Non     completed  2025-04-14 17:54:52
# 140  Non, hÃ¢te de voir la suite     completed  2025-04-14 16:40:18
# 141                        R.A.S     completed  2025-04-14 15:28:07
# 142                          NaN     completed  2025-04-14 15:03:58
# 143                          NaN     completed  2025-04-14 14:45:21
#
#     Stage Date (UTC)    Submit Date (UTC)  Network ID Tags
# 0                NaN  2025-05-13 09:12:46  4adfa917dd  NaN
# 1                NaN  2025-05-13 09:10:13  4adfa917dd  NaN
# 2                NaN  2025-05-13 09:05:28  3b969b652a  NaN
# 3                NaN  2025-05-13 09:07:52  4adfa917dd  NaN
# 4                NaN  2025-05-13 09:06:42  4adfa917dd  NaN
# ..               ...                  ...         ...  ...
# 139              NaN  2025-04-14 17:56:55  9f78c2ed85  NaN
# 140              NaN  2025-04-14 16:45:32  e8303a6170  NaN
# 141              NaN  2025-04-14 15:30:10  556b0bb459  NaN
# 142              NaN  2025-04-14 15:06:21  4e863fcb02  NaN
# 143              NaN  2025-04-14 14:49:48  e0b8e56cad  NaN
#
# [144 rows x 21 columns]

# %% [markdown]
# ### Création des variables
#
# - Liste de tout les cours
# - liste de tout les élèves

# %%
liste_cours = df_test["Quel module veux-tu renseigner ? "].unique().tolist()

# %%
liste_cours
# Out:
# ['Bien démarrer sur Illustrator',
#  'Charte graphique',
#  "Comprendre le web et l'e-commerce",
#  "Concevoir l'interface (UI)",
#  'Concevoir la navigation (UX)',
#  'Connaître et maîtriser les principes et les règles du référencement naturel',
#  'Créer un support print sur Illustrator / PhotoShop',
#  'CV et Lettre de motivation',
#  'Développer et optimiser son site sous PrestaShop',
#  'Développer et optimiser son site sous WordPress',
#  "Droit de l'internet & RGPD",
#  'Exporter et diffuser une vidéo',
#  'HTML/ CSS/ JS',
#  'Introduction au webdesign',
#  "Maîtriser l'outil Google Slides",
#  "Maîtriser les bases d'Adobe PhotoShop",
#  'Maîtriser les bases de la photographie e-commerce',
#  'Montage vidéo',
#  "Savoir concevoir une campagne d'emailing",
#  'Savoir réaliser un cahier des charges (partie 1)',
#  'Savoir réaliser un cahier des charges (partie 2)',
#  'Soft skills 1',
#  'Soft Skills 2',
#  'Soft skills 3',
#  'Soft skills 4',
#  'Soft skills 5',
#  'Soft skills 6',
#  'Soft skills 7',
#  'Soft skills 8',
#  "Techniques et méthodes d'impression",
#  'Tests utilisateurs',
#  "UX/UI : Comprendre les utilisateurs pour scénariser l'UX",
#  'Veille sur internet']

# %%
liste_apprenants = df_apprenants_CDP2["Prénom"].unique().tolist()

# %%
liste_apprenants
# Out:
# ['Soumaya',
#  'Nouha',
#  'Enza',
#  'Zaccaria',
#  'Rafik Mohamed',
#  'Marwan',
#  'Houssam',
#  'Manon',
#  'Mehdi',
#  'Mohammed',
#  'Sofiane',
#  'Elodie',
#  'Laszlo',
#  'Fahar-Dine',
#  'Amar']

# %% [markdown]
# ## Analyse global
#
# ```{note}
#
# Générer un histogramme avec le nombre de réponses par module
# - Utiliser le
#
# - créer un diagramme matricielle qui nous montre un oui - non avec des couleurs différentes
#
# ```
#
# ### Créer un dictionnaire

# %%
# Créer un dictionnaire associant chaque cours aux étudiants ayant donné des réponses
feedback = df_CDP2.groupby("Quel module veux-tu renseigner ? ")["Quel est ton prÃ©nomâ¯?"].apply(list).to_dict()

# %%
feedback
# Out:
# {'Bien dÃ©marrer illustrator partie 1': ['Amar',
#   'Zaccaria',
#   'laszlo',
#   'Fahar-Dine',
#   'Elodie',
#   'Soumaya',
#   'Enza',
#   'Marwan',
#   'Houss',
#   'Nouha',
#   'Manon',
#   'Mehdi',
#   'Mohammed'],
#  'Bien dÃ©marrer illustrator partie 2': ['Manon',
#   'Amar',
#   'Houss',
#   'laszlo',
#   'Fahar-Dine',
#   'Zaccaria',
#   'Soumaya',
#   'Marwan',
#   'Elodie',
#   'Enza',
#   'Zaccaria',
#   'Nouha',
#   'Mohammed',
#   'Mehdi'],
#  'Bien dÃ©marrer illustrator partie 3': ['Manon',
#   'Amar',
#   'Houss',
#   'laszlo',
#   'Zaccaria',
#   'Soumaya',
#   'Fahar-Dine',
#   'Marwan',
#   'Elodie',
#   'Enza',
#   'Nouha',
#   'Mohammed'],
#  'Charte graphique': ['laszlo',
#   'Soumaya',
#   'Zaccaria',
#   'Fahar-Dine',
#   'Nouha',
#   'Elodie',
#   'Enza',
#   'Houss',
#   'Mohammed',
#   'Mehdi'],
#  "Comprendre l'impact du Marketing dans le digital": ['Houss',
#   'Fahar-Dine',
#   'Marwan',
#   'Nouha',
#   'Enza',
#   'Soumaya',
#   'Mehdi',
#   'Mohammed',
#   'Elodie',
#   'Zaccaria'],
#  "Comprendre les utilisateurs pour scÃ©nariser l'UX": ['Houss',
#   'Zaccaria',
#   'Nouha',
#   'Enza',
#   'Soumaya',
#   'Fahar-Dine',
#   'Elodie',
#   'Mohammed'],
#  'Introduction au webdesign': ['Fahar-Dine', 'Laszlo'],
#  "MaÃ®triser l'outil Canva": ['Manon',
#   'laszlo',
#   'Nouha',
#   'Soumaya',
#   'Marwan',
#   'Elodie',
#   'Enza',
#   'Fahar-Dine',
#   'Mohammed'],
#  'Savoir rÃ©aliser un benchmark digital': ['laszlo',
#   'Manon',
#   'Nouha',
#   'Marwan',
#   'Fahar-Dine',
#   'Mohammed',
#   'Amar',
#   'Zaccaria',
#   'Soumaya',
#   'Elodie'],
#  'Savoir rÃ©aliser un cahier des charges': ['Manon',
#   'Zaccaria',
#   'Enza',
#   'Nouha',
#   'Fahar-Dine',
#   'Marwan',
#   'Manon',
#   'Mehdi',
#   'Elodie',
#   'Soumaya',
#   'Mohammed'],
#  'Soft skills 1': ['Marwan',
#   'Zaccaria',
#   'Enza',
#   'Fahar-Dine',
#   'Nouha',
#   'Elodie',
#   'Soumaya',
#   'Manon',
#   'Mohammed',
#   'Mehdi',
#   'Amar'],
#  'Soft skills 2': ['Amar',
#   'Zaccaria',
#   'Marwan',
#   'Enza',
#   'Elodie',
#   'Enza',
#   'Fahar-Dine',
#   'Laszlo',
#   'Nouha',
#   'Mohammed',
#   'Manon',
#   'Ã\x89lodie',
#   'Soumaya'],
#  'Soft skills 3': ['Enza',
#   'Fahar-Dine',
#   'Marwan',
#   'Elodie',
#   'Soumaya',
#   'Mohammed',
#   'Nouha',
#   'Zaccaria',
#   'Manon',
#   'Amar'],
#  'Veille sur internet': ['Houss',
#   'Nouha',
#   'laszlo',
#   'Zaccaria',
#   'Fahar-Dine',
#   'Marwan',
#   'Soumaya',
#   'Elodie',
#   'Enza',
#   'Mohammed',
#   'Mehdi']}

# %% [markdown]
# ### Graph
#
# ```{note}
#
# Insérer la date du jour dans le titre
#
# ```

# %%
# Extraction des listes d'étudiants et de cours
etudiants = sorted({etudiant for etudiants_list in feedback.values() for etudiant in etudiants_list})
cours = sorted(feedback.keys())

# Matrice des couleurs (True si feedback trouvé, False sinon)
colors = np.zeros((len(etudiants), len(cours)), dtype=bool)

for i, etudiant in enumerate(etudiants):
    for j, cour in enumerate(cours):
        colors[i, j] = etudiant in feedback.get(cour, [])

# Création du diagramme
fig, ax = plt.subplots(figsize=(15, 9))
cmap = plt.cm.RdYlGn  # Rouge pour False, Vert pour True
im = ax.imshow(colors, cmap=cmap, interpolation='nearest')

# Configuration des axes
ax.set_xticks(np.arange(len(cours)))
ax.set_yticks(np.arange(len(etudiants)))
ax.set_xticklabels(cours)
ax.set_yticklabels(etudiants)

# Rotation des noms de colonnes (cours)
plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

# Ajout des valeurs dans les cases
for i in range(len(etudiants)):
    for j in range(len(cours)):
        text = "✔" if colors[i, j] else "✘"
        ax.text(j, i, text, ha="center", va="center", color="black")

# Titre et ajustement
ax.set_title("Feedbacks Apprenants 13/05/2025")
plt.savefig("Resultats/feedbacks-apprenants-13-05-25.png", dpi=300, bbox_inches="tight")
fig.tight_layout()
plt.show()
# Out:
# C:\Users\vdegu\AppData\Local\Temp\ipykernel_7316\920651374.py:34: UserWarning: Glyph 137 (\x89) missing from font(s) DejaVu Sans.
#   plt.savefig("Resultats/feedbacks-apprenants-13-05-25.png", dpi=300, bbox_inches="tight")
# C:\Users\vdegu\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 137 (\x89) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### To do
#
# - Insérer la date en début de notebook

# %% [markdown]
# ## Post processing

# %%
# Afficher des statistiques descriptives
print(df_test.describe())

# Afficher les noms des colonnes
print(df_test.columns)
# Out:
#        Pourquoi ?
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN
# Index(['Quel est ton nom de famille ?', 'Quel est ton prénom ?',
#        'Quel module veux-tu renseigner ? ',
#        'Comment te sens-tu à l'issue de ce module ?', 'Pourquoi ?',
#        'Le contenu  du module était-il adapté à tes attentes ?',
#        'Pourquoi ?.1',
#        'As-tu le sentiment de maîtriser ce qui a été vu dans le module ?',
#        'Lesquels ?', 'Pourquoi ?.2',
#        'Peux-tu partager une chose que tu as retenue de ce module ?',
#        'Comment as-tu trouvé lea formateur.trice ?',
#        'As-tu des idées pour améliorer le cours ?', 'D’autres remarques ?',
#        'Submitted At', 'Token'],
#       dtype='object')

# %%
df_filtre = df_test[df_test['Quel module veux-tu renseigner ? '] == "Soft skills 1"]

# %%
#df_filtre

# %% [markdown]
# ## Résultats
#
# ### Pourcentage de réponse
#
# mettre nombre d'apprenants dans une variable

# %%
pourcentage = len(df_filtre) / 17 * 100

# %%
pourcentage
# Out:
# 82.35294117647058

# %% [markdown]
# ## Figures
#
# ### Comment te sens-tu à l'issue de ce module ?
#
# - histogramme / cammembert ?

# %%
valeurs_uniques = df_filtre["Comment te sens-tu à l'issue de ce module ?"].value_counts()
print(valeurs_uniques)
# Out:
# Comment te sens-tu à l'issue de ce module ?
# J’ai appris de manière satisfaisante    10
# Je n'ai pas appris grand-chose           2
# J’ai beaucoup appris                     2
# Name: count, dtype: int64

# %%
# Création d'un histogramme
valeurs_uniques.plot(kind='bar', color='skyblue', edgecolor='black')

# Ajouter un titre et des labels
plt.title('Résultat')
plt.xlabel('réponses')
plt.ylabel('Nombre de réponses')

# Afficher le graphique
plt.show()

# %% [markdown]
# ## Idée amélioration du feedback
#
# - Rajouter la date du cours,
#
# ```{note}
#
# peut-être l'inclure manuellement pour pas surcharger le formulaire
#
# ```
